# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as scs
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/patrickbrown/anaconda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# **1)** Load the data into a dataframe from `data/balance.csv`. Make a scatter matrix of the variables. Comment on the distribution of your variables and describe the relationships between your numeric feature variables and Balance.

# %%
balance = pd.read_csv('data/balance.csv', index_col=0)
balance.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 1   14.891   3606     283      2   34         11    Male      No     Yes
# 2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 3  104.593   7075     514      4   71         11    Male      No      No
# 4  148.924   9504     681      3   36         11  Female      No      No
# 5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580
# 4      Asian      964
# 5  Caucasian      331

# %% [markdown]
# The _features_ in this dataset are:
# * Income of individual
# * credit limit of individual
# * credit rating of individual
# * cards (number of cards)
# * Age in years of individuals (in whole years)
# * Education (in years)
# * Gender (binary)
# * Student or not (binary)
# * Married or not (binary)
# * Ethnicity (categorical)
# * Balance (presumably on credit cards)

# %%
pd.scatter_matrix(balance, figsize=(15, 10))
plt.show()
# Out:
# /Users/patrickbrown/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Balance shows strong positive correlation to credit rating and limit.  The relationship to income is somewhat less well-defined with probable additional factors at play.

# %% [markdown]
# **2)** Since Gender, Student and Married are boolean variables, convert the columns to 1/0, i.e. the value should be 1 if the response to Married is Yes, otherwise 0.

# %% [markdown]
# First we'll tackle the gender column.  First try a simple replace threw the values out because the current series type of gender, married is 'object' and in replacing this was interpreted as a float and led to a lot of NAN values.  Instead, we used map, but also have to tidy up values by using the fillna method to replace the Nans we know to connote 0s in the gender column (or Male) with the values we want.
#
# The married column behaves more straightforwardly.

# %%
gender_vals = {'Male': '0', 'Female':'1'}
balance['Gender'] = balance['Gender'].map(gender_vals)

# %%
balance['Gender'].fillna(value=0, inplace=True)

# %%
balance['Gender'].value_counts()
# Out:
# 1    207
# 0    193
# Name: Gender, dtype: int64

# %%
balance['Gender'].astype(int)
balance.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education Gender Student Married  \
# 1   14.891   3606     283      2   34         11      0      No     Yes
# 2  106.025   6645     483      3   82         15      1     Yes     Yes
# 3  104.593   7075     514      4   71         11      0      No      No
# 4  148.924   9504     681      3   36         11      1      No      No
# 5   55.882   4897     357      2   68         16      0      No     Yes
#
#    Ethnicity  Balance
# 1  Caucasian      333
# 2      Asian      903
# 3      Asian      580
# 4      Asian      964
# 5  Caucasian      331

# %%
married_vals = {'No': '0', 'Yes':'1'}
balance['Married'] = balance['Married'].map(married_vals)

# %%
student_vals = {'No': '0', 'Yes':'1'}
balance['Student'] = balance['Student'].map(student_vals)

# %%
balance['Student'] = balance['Student'].astype(int)
balance['Gender'] = balance['Gender'].astype(int)
balance['Married'] = balance['Married'].astype(int)

# %% [markdown]
# **3)** Since Ethnicity is a categorical variable that has more than 2 categories, we need to convert the categories within the variable to separate columns with binary responses. These are known as dummy variables. Use get_dummies in pandas to get create dummy variables for Ethnicity. After you create the model, drop the African dummy variable. It can be any dummy variable you want the rest of the dummies to be compared against.

# %%
dummy_ranks = pd.get_dummies(balance['Ethnicity'], prefix='Ethnicity')
dummy_ranks.head()
# Out:
#    Ethnicity_African American  Ethnicity_Asian  Ethnicity_Caucasian
# 1                           0                0                    1
# 2                           0                1                    0
# 3                           0                1                    0
# 4                           0                1                    0
# 5                           0                0                    1

# %%
cols_to_keep = ['Income','Limit','Rating','Cards','Age','Education','Gender','Student','Married','Balance']
balance = balance[cols_to_keep].join(dummy_ranks.ix[:, 'Ethnicity_Asian':])
balance.head()
# Out:
# /Users/patrickbrown/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#     Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1   14.891   3606     283      2   34         11       0        0        1
# 2  106.025   6645     483      3   82         15       1        1        1
# 3  104.593   7075     514      4   71         11       0        0        0
# 4  148.924   9504     681      3   36         11       1        0        0
# 5   55.882   4897     357      2   68         16       0        0        1
#
#    Balance  Ethnicity_Asian  Ethnicity_Caucasian
# 1      333                0                    1
# 2      903                1                    0
# 3      580                1                    0
# 4      964                1                    0
# 5      331                0                    1

# %%
balance['Ethnicity_Asian'] = balance['Ethnicity_Asian'].astype(int)
balance['Ethnicity_Caucasian'] = balance['Ethnicity_Asian'].astype(int)

# %%
balance['intercept'] = 1.0

# %%
balance.dtypes
# Out:
# Income                 float64
# Limit                    int64
# Rating                   int64
# Cards                    int64
# Age                      int64
# Education                int64
# Gender                   int64
# Student                  int64
# Married                  int64
# Balance                  int64
# Ethnicity_Asian          int64
# Ethnicity_Caucasian      int64
# intercept              float64
# dtype: object

# %%
balance.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1   14.891   3606     283      2   34         11       0        0        1
# 2  106.025   6645     483      3   82         15       1        1        1
# 3  104.593   7075     514      4   71         11       0        0        0
# 4  148.924   9504     681      3   36         11       1        0        0
# 5   55.882   4897     357      2   68         16       0        0        1
#
#    Balance  Ethnicity_Asian  Ethnicity_Caucasian  intercept
# 1      333                0                    0        1.0
# 2      903                1                    1        1.0
# 3      580                1                    1        1.0
# 4      964                1                    1        1.0
# 5      331                0                    0        1.0

# %% [markdown]
# **4)** Using all the feature variables, fit a linear regression model to predict Balance.

# %%
X = balance[['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Gender', 'Student', 'Married', 'Ethnicity_Asian', 'Ethnicity_Caucasian']]
y = balance['Balance']

X = sm.add_constant(X)
est = sm.OLS(y,X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     826.0
# Date:                Sun, 16 Jul 2017   Prob (F-statistic):          5.32e-255
# Time:                        11:38:15   Log-Likelihood:                -2399.0
# No. Observations:                 400   AIC:                             4820.
# Df Residuals:                     389   BIC:                             4864.
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                -471.6100     34.562    -13.645      0.000    -539.562    -403.658
# Income                 -7.8070      0.234    -33.350      0.000      -8.267      -7.347
# Limit                   0.1911      0.033      5.833      0.000       0.127       0.256
# Rating                  1.1334      0.491      2.310      0.021       0.169       2.098
# Cards                  17.7306      4.339      4.086      0.000       9.199      26.262
# Age                    -0.6217      0.294     -2.117      0.035      -1.199      -0.044
# Education              -1.1375      1.597     -0.712      0.477      -4.277       2.002
# Gender                -10.6066      9.910     -1.070      0.285     -30.090       8.877
# Student               425.5740     16.715     25.461      0.000     392.712     458.436
# Married                -7.8749     10.328     -0.762      0.446     -28.181      12.431
# Ethnicity_Asian         4.9873      5.726      0.871      0.384      -6.271      16.246
# Ethnicity_Caucasian     4.9873      5.726      0.871      0.384      -6.271      16.246
# ==============================================================================
# Omnibus:                       34.416   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.111
# Skew:                           0.777   Prob(JB):                     1.18e-09
# Kurtosis:                       3.221   Cond. No.                     9.41e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **5)** Plot the histogram for Balance. What do you observe?

# %% [markdown]
# You should find that various Balance values are fitted around the 0 point. It would seem that the abundance of obseravtions at 0 balance is affecting how the model is fitted. Plot the histogram for Balance again, except set bins=100. What do you observe?

# %%
# Plotting the histogram for the Balance (y)
y.hist(bins=100)
plt.show()

# %% [markdown]
# **6)** Re-plot the univariate scatter plot on a bigger figure size. Look for variable(s) that can differentiate most zero balance observation from non-zero balance observations. Use the provided pandas code as a reference.

# %%
all_columns = balance.columns

for col in all_columns:
    balance.plot(kind='scatter', y='Balance', x=col, edgecolor='none', figsize=(12, 5))
    plt.xlabel(col)
    plt.ylabel('Balance')
    plt.show()

# %% [markdown]
# **7)** Once you find the relevant variable(s), decide on a threshold that would give you reasonable separation between the zero and non-zero obseravations, i.e. minimize false positive and false negative predictions. You can do it visually based on your plot now, but a slightly more sophisticated way to model this would be with a
# Decision Tree which we will cover later in the course.

# %%
# For rating, this should be at a level of about 200.

sns.lmplot(x="Rating", y='Balance', data=balance)

# %%
# For Limit, this could be set at a level of about 1800

sns.lmplot(x="Limit", y='Balance', data=balance)

# %%
# For income, it is difficult to determine, but perhaps start at 10,000 (10.00)

sns.lmplot(x="Income", y='Balance', data=balance)

# %% [markdown]
# **8)** Remove the data points below the decided threshold of your chosen variable and examine the number of zero obseravations that remain.
#
# This is an atypical first step for linear regression but works well in this situation because we have a large loading of 0 observations in our response, which are affecting the regression fit. In essence, we are fitting two models, one feeding into the other. The first model simply predicts 0 or non-zero balance based on a single feature, the second model predicts the balance given that the first model predicted non-zero balance.

# %%
# we opt for rating as offering the best fit. Income is too dispersed and setting a threshold would perhaps be too
# distortive.  Rating and limit show very similar data patterns, and setting thresholds for both might be duplicating 
# effort.

balance[(balance['Rating'] > 200)&(balance['Balance'] >= 1)]

# a rating above 200 gives us a decent threshold for exclusion of the excess zero values
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender  Student  Married  \
# 1     14.891   3606     283      2   34         11       0        0        1
# 2    106.025   6645     483      3   82         15       1        1        1
# 3    104.593   7075     514      4   71         11       0        0        0
# 4    148.924   9504     681      3   36         11       1        0        0
# 5     55.882   4897     357      2   68         16       0        0        1
# 6     80.180   8047     569      4   77         10       0        0        0
# 7     20.996   3388     259      2   37         12       1        0        0
# 8     71.408   7114     512      2   87          9       0        0        0
# min           0.000000             0.000000        1.0
# 25%           0.000000             0.000000        1.0
# 50%           0.000000             0.000000        1.0
# 75%           0.000000             0.000000        1.0
# max           1.000000             1.000000        1.0

# %%
sns.lmplot(x="Rating", y='Balance', data=balance)

# %% [markdown]
# **9)** Now re-fit the same model and examine the residuals. It might still be skewed, but should resemble more of a normal distribution. While it's important to strive for models that pass the model diagnostic tests, in practice we sometimes loosen the restrictions a bit.

# %%
X2 = balance[['Rating', 'Limit', 'Income']]
y2 = balance['Balance']

X2 = sm.add_constant(X2)
est2 = sm.OLS(y2,X2).fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     765.1
# Date:                Sun, 16 Jul 2017   Prob (F-statistic):          2.03e-147
# Time:                        11:42:20   Log-Likelihood:                -2136.1
# No. Observations:                 331   AIC:                             4280.
# Df Residuals:                     327   BIC:                             4296.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -641.7055     37.423    -17.147      0.000    -715.326    -568.085
# Rating         2.2835      0.692      3.302      0.001       0.923       3.644
# Limit          0.1529      0.047      3.278      0.001       0.061       0.245
# Income        -9.1228      0.390    -23.404      0.000      -9.890      -8.356
# ==============================================================================
# Omnibus:                      151.202   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              459.110
# Skew:                           2.197   Prob(JB):                    2.02e-100
# Kurtosis:                       6.740   Cond. No.                     2.53e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# This model shows a fairly high Adjusted R2, particularly compared to the 'kitchen sink' approach we took earlier by adding all the features as predictors and seeing the result.
#
# The reason we focus on Adjusted R^2 is due to two main problems:
#
# * Problem 1: Every time you add a predictor to a model, the R-squared increases, even if due to chance alone. It never decreases. Consequently, a model with more terms may appear to have a better fit simply because it has more terms.
#
# * Problem 2: If a model has too many predictors and higher order polynomials, it begins to model the random noise in the data. This condition is known as overfitting the model and it produces misleadingly high R-squared values and a lessened ability to make predictions.
#
# Comparing the explanatory power of a five-predictor model with a higher R^2 to a one predictor model risks confusing whether the higher R^2 is a function of the more-features model being better or because it's simply got more features.
#
# The adjusted R-squared is a modified version of R-squared that has been adjusted for the number of predictors in the model. The adjusted R-squared increases only if the new term improves the model more than would be expected by chance. It decreases when a predictor improves the model by less than expected by chance. The adjusted R-squared can be negative, but it’s usually not.  It is always lower than the R-squared.

# %% [markdown]
# **10)** Try out a few different models using different sets of features. This can be a bit of an art, but some guidelines you can use are to (i) exclude features which don't have statistically significant beta coefficients and (ii) exclude features with high variance inflation factor or high collinearity with another feature already in the model.
#
# To decide among the models, you can use adjusted R^2 or F-tests. Tomorrow we'll get into a more general model-evaluation technique called cross-validation.

# %%
X3 = balance[['Rating', 'Income', 'Limit', 'Age', 'Married']]
y3 = balance['Balance']

X3 = sm.add_constant(X3)
est3 = sm.OLS(y3,X3).fit()
est3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     474.0
# Date:                Sun, 16 Jul 2017   Prob (F-statistic):          6.84e-147
# Time:                        11:42:34   Log-Likelihood:                -2130.6
# No. Observations:                 331   AIC:                             4273.
# Df Residuals:                     325   BIC:                             4296.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -559.3758     45.391    -12.324      0.000    -648.672    -470.079
# Rating         2.4513      0.684      3.582      0.000       1.105       3.798
# Income        -8.9576      0.389    -23.025      0.000      -9.723      -8.192
# Limit          0.1414      0.046      3.063      0.002       0.051       0.232
# Age           -1.3031      0.498     -2.619      0.009      -2.282      -0.324
# Married      -37.7574     17.292     -2.183      0.030     -71.776      -3.739
# ==============================================================================
# Omnibus:                      151.057   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              457.180
# Skew:                           2.197   Prob(JB):                    5.30e-100
# Kurtosis:                       6.720   Cond. No.                     3.12e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.12e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# We experimented with different inputs here. Gender added little to the model aside from these predictors, and showed a P>|t| > 0.05. Similarly, ethnicity_asian added little.
#
# Intuitively, it feels right that credit rating, limit, age and income should be good predictors of an individual's credit card balance (backed by the objective evidence).  Marriage also turns out to be a helpful predictor, but this may also be related to age in some way.
#
# Heatmapping confirms our thoughts, as does the results of the linear regression.

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)

correlations = balance[['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Gender', 'Student', 'Married', 'Ethnicity_Asian', 'Ethnicity_Caucasian']].corr()
print correlations
print sns.heatmap(correlations, cmap=cmap)
# Out:
#                        Income     Limit    Rating     Cards       Age  \
# Income               1.000000  0.796122  0.793642 -0.020206  0.196261
# Limit                0.796122  1.000000  0.996413  0.008536  0.142123
# Rating               0.793642  0.996413  1.000000  0.055048  0.144835
# Cards               -0.020206  0.008536  0.055048  1.000000  0.045344
# Age                  0.196261  0.142123  0.144835  0.045344  1.000000
# Education           -0.034393 -0.043896 -0.050593 -0.061437  0.010130
# Gender              -0.010461  0.013887  0.014910 -0.022757  0.003763
# Student              0.034644  0.015790  0.021025 -0.010985 -0.027261
# Married              0.043363  0.053124  0.056698 -0.013998 -0.045034
# Ethnicity_Asian     -0.003881 -0.012651 -0.016552  0.011245 -0.055217
# Ethnicity_Caucasian -0.003881 -0.012651 -0.016552  0.011245 -0.055217
#
#                      Education    Gender   Student   Married  Ethnicity_Asian  \
# Income               -0.034393 -0.010461  0.034644  0.043363        -0.003881
# Limit                -0.043896  0.013887  0.015790  0.053124        -0.012651
# Rating               -0.050593  0.014910  0.021025  0.056698        -0.016552
# Cards                -0.061437 -0.022757 -0.010985 -0.013998         0.011245
# Age                   0.010130  0.003763 -0.027261 -0.045034        -0.055217
# Education             1.000000  0.012013  0.068687  0.058305         0.056056
# Gender                0.012013  1.000000  0.055459  0.024302         0.008123
# Student               0.068687  0.055459  1.000000 -0.120649         0.050194
# Married               0.058305  0.024302 -0.120649  1.000000         0.068064
# Ethnicity_Asian       0.056056  0.008123  0.050194  0.068064         1.000000
# Ethnicity_Caucasian   0.056056  0.008123  0.050194  0.068064         1.000000
#
#                      Ethnicity_Caucasian
# Income                         -0.003881
# Limit                          -0.012651
# Rating                         -0.016552
# Cards                           0.011245
# Age                            -0.055217
# Education                       0.056056
# Gender                          0.008123
# Student                         0.050194
# Married                         0.068064
# Ethnicity_Asian                 1.000000
# Ethnicity_Caucasian             1.000000
# Axes(0.125,0.125;0.62x0.755)

# %% [markdown]
# ## Extra Credit
#
# Interactions, Polynomials, Transformations, etc.

# %% [markdown]
# **1)** Fit a linear model to predict Balance using Income as a predictor. Fit a second model using Income and Student as predictors. Finally fit a model using Income, Student, and IncomexStudent to account for a possible interaction effect between Income and Student. How do the models compare? Is the interaction term significant?
# If the interaction term is significant, make a single plot with two regression lines, one for Student and one for non-Students. You should have Balance on the y-axis, Income on the x-axis, and Student or non-Student coded in using two different colors (add a legend).
# Since the models are nested such that each model has one more predictor than the previous, you can simply look at the p-values to make some comparisons. This is in essence a t-test, which is equivalent to performing an F-test.

# %%
X_new_sub = new_balance['Income']
summary = summary_model(X_new_sub, y_new, label='Income')
print summary

X_new_sub = new_balance[['Income', 'Student']]
summary = summary_model(X_new_sub, y_new, 'Income/Student')
print summary


new_balance.loc[:, 'Income*Student'] = new_balance['Income'] * new_balance['Student']
X_new_sub = new_balance[['Income', 'Student', 'Income*Student']]
summary = summary_model(X_new_sub, y_new, 'Income/Student Interaction')
print summary
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     43.55
# Date:                Fri, 06 Jan 2017   Prob (F-statistic):           1.85e-10
# Time:                        14:35:07   Log-Likelihood:                -2246.1
# No. Observations:                 304   AIC:                             4496.
# Df Residuals:                     302   BIC:                             4504.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        470.2326     38.301     12.277      0.000       394.862   545.604
# Income         3.9435      0.598      6.599      0.000         2.768     5.119
# ==============================================================================
# Omnibus:                       19.144   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.559
# Skew:                           0.056   Prob(JB):                       0.0228
# Kurtosis:                       2.236   Cond. No.                         109.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     45.37
# Date:                Fri, 06 Jan 2017   Prob (F-statistic):           5.99e-18
# Time:                        14:35:07   Log-Likelihood:                -2226.5
# No. Observations:                 304   AIC:                             4459.
# Df Residuals:                     301   BIC:                             4470.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        430.6873     36.494     11.802      0.000       358.872   502.502
# Income         3.8377      0.561      6.835      0.000         2.733     4.943
# Student      456.3022     70.940      6.432      0.000       316.700   595.904
# ==============================================================================
# Omnibus:                       30.490   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.567
# Skew:                          -0.027   Prob(JB):                      0.00837
# Kurtosis:                       2.133   Cond. No.                         216.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     32.06
# Date:                Fri, 06 Jan 2017   Prob (F-statistic):           5.27e-18
# Time:                        14:35:07   Log-Likelihood:                -2224.3
# No. Observations:                 304   AIC:                             4457.
# Df Residuals:                     300   BIC:                             4471.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# const            408.9087     37.739     10.835      0.000       334.641   483.176
# Income             4.2607      0.594      7.179      0.000         3.093     5.429
# Student          657.6350    118.979      5.527      0.000       423.496   891.774
# Income*Student    -3.6768      1.750     -2.101      0.036        -7.120    -0.233
# ==============================================================================
# Omnibus:                       28.052   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.313
# Skew:                          -0.064   Prob(JB):                      0.00950
# Kurtosis:                       2.152   Cond. No.                         367.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/giovanna/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/giovanna/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# When we added Student to Income, the model's accuracy in terms of Adjusted R^2 went up. The interaction (Income * Student) is also significant, and our model's accuracy in terms of Adjusted R^2 also increases.

# %% [markdown]
# **2)** Return to your final model in 10. Can you improve upon this fit by making transformations to your selected features?
# Generally, there is no defined end to the modeling process so this step can take as long as you would like. At some point you just have to stop!
